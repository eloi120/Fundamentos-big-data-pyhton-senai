# %% [markdown]
# ### Situação problema
# Você é o proprietário de uma sorveteria que opera em uma cidade ensolarada.
# Como proprietário, você deseja maximizar seus lucros e garantir que seu
# estoque de sorvetes seja gerenciado eficientemente. Para fazer isso, você
# decidiu criar um modelo de previsão de vendas de sorvetes com base na
# temperatura diária.
# Foram coletados dados históricos de temperatura e receita em dólares ao longo
# de vários meses para criar um modelo de regressão linear. Seu objetivo é
# prever a receita diária em dólares com base na temperatura do ar externo (em
# graus Celsius) para que você possa tomar decisões informadas sobre o estoque
# e a produção de sorvetes.

# %%
# Importando as bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## ETAPA #02: IMPORTANDO O DATASET

# %%
dados = pd.read_csv('./Arquivos/IceCreamData.csv')
dados.head(1)

# %% [markdown]
# ## Etapa 03: visualizando o dataset
# *CABEÇALHO >> df.head()
# *ÚLTIMAS LINHAS >> df.tail()
# *DESCRIBE >> df.describe()
# *INFO DOS TIPOS DE DADOS >> df.info()

# %%
dados.tail(1)

# %%
dados.describe()

# %%
dados.info()

# %% [markdown]
# ### ETAPA 04: GERAR ALGUMAS VISUALIZAÇÕES GRÁFICAS

# %%
sns.jointplot(data = dados, x = 'Temperature',y = 'Revenue', color = 'gray')

# %%
sns.pairplot(dados)

# %%
sns.lmplot(x='Temperature', y='Revenue', data=dados)
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### ETAPA 05: CRIAR E TESTAR O MODELO

# %%
# CRIAÇÃO DA VARIÁVEL DEPENDENTE (Y) > resposta
y = dados['Revenue']

# CRIAÇÃO DA VARÁVEL INDEPENDENTE (X) > ENTRADA
X = dados[['Temperature']]

# SEPARAR OS DADOS PARA TESTE E TREINO

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25)

# %% [markdown]
# ### ETAPA 06: TREINANDO O MODELO

# %%
#CRIAÇÃO DO MODELO
modelo = LinearRegression()

#TREINAMENTO DO MODELO
modelo.fit(X_train,y_train)

# EXIBIÇÃO DOS COEFICIENTES
print('Coeficiente linear (b):', modelo.intercept_)
print('Coeficiente angular (a):', modelo.coef_)
# Out:
# Coeficiente linear (b): 47.768142710671384
# Coeficiente angular (a): [21.33184469]

# %% [markdown]
# ### ETAPA 07: TESTANDO O MODELO

# %%
y_predict = modelo.predict(X_test)
y_predict
# Out:
# array([510.33694367, 571.43413855, 673.04744191, 474.03957482,
#        708.31055888, 354.51360534, 434.91877527, 487.10463129,
#        563.65613628, 538.47499307, 451.12108587, 582.26483361,
#        369.94132722, 268.04907694, 590.00874355, 523.70460814,
#        836.98419121, 573.14185789,  68.6065816 , 622.80470064,
#        600.79986398, 804.15559704, 627.69162595, 470.51281507,
#        723.33624247, 411.47049737, 671.54865306, 364.88955304,
#        740.30585483, 372.32297457, 681.71891464, 732.6713843 ,
#        531.00131771, 681.47376097, 212.98937985, 564.91845608,
#        476.62142515, 605.08906567, 327.48093737, 807.79883656,
#        570.25919079, 635.95025346, 635.28897609, 362.02512894,
#        270.62461411, 510.92526507, 517.27936309, 666.25803838,
#        525.55831537, 571.82510562, 590.06982302, 577.19793921,
#        285.2492923 , 368.36682057, 448.31255717, 504.79348178,
#        307.79091283, 670.33898239, 524.79943691, 570.07641058,
# ...

# %%
minha_previsao = modelo.predict([[41]])

minha_previsao
# Out:
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([922.3737749])
