# %%
# Importação das biliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Mapeando o arquivo
caminhoArquivo = './Arquivos/dados-satisfação.xlsx'

# Alocando o arquivo
dados = pd.read_excel(caminhoArquivo, sheet_name = 'treino')

dados
# Out:
#                   Instituição  \
# 0             Banco do Brasil
# 1             Banco do Brasil
# 2             Banco do Brasil
# 3             Banco do Brasil
# 4             Banco do Brasil
# ...                       ...
# 8697  Caixa Econômica Federal
# 8698  Caixa Econômica Federal
# 8699  Caixa Econômica Federal
# 8700  Caixa Econômica Federal
# 8701  Caixa Econômica Federal
#
#                                              Comentario       Data  \
# 0                                 Muito bom ajuda muito 2019-07-21
# 1                                             excelente 2019-07-21
# 2                                                   Bom 2019-07-21
# 3                                  aplicativo muito top 2019-07-21
# 4                                       Fácil e prático 2019-07-21
# ...                                                 ...        ...
# 8697                                          Muito bom 2020-08-24
# 8698                                                Top 2020-08-24
# 8699  A facilidade de resolver minhas movimentação b... 2020-08-24
# 8700                           Péssimo ,vou desinstalar 2020-08-24
# 8701                                                Boa 2020-08-24
#
#       Classificação Elogio quanto ao app Reclamação quanto ao app  \
# 0                 5                  SIM                      NÃO
# 1                 5                  SIM                      NÃO
# 2                 5                  SIM                      NÃO
# 3                 5                  SIM                      NÃO
# 4                 5                  SIM                      NÃO
# ...             ...                  ...                      ...
# 8697              5                  SIM                      NÃO
# 8698              5                  SIM                      NÃO
# 8699              5                  SIM                      NÃO
# 8700              1                  NÃO                      SIM
# 8701              5                  SIM                      NÃO
#
#      Elogio a Instituição Reclamação a Instituição Não Classificável
# 0                     NÃO                      NÃO               NÃO
# 1                     NÃO                      NÃO               NÃO
# 2                     NÃO                      NÃO               NÃO
# 3                     NÃO                      NÃO               NÃO
# 4                     NÃO                      NÃO               NÃO
# ...                   ...                      ...               ...
# 8697                  NÃO                      NÃO               NÃO
# 8698                  NÃO                      NÃO               NÃO
# 8699                  NÃO                      NÃO               NÃO
# 8700                  NÃO                      NÃO               NÃO
# 8701                  NÃO                      NÃO               NÃO
#
# [8702 rows x 9 columns]

# %%
# substituindo os dados
dados['Elogio a Instituição'] = dados['Elogio a Instituição'].replace('SIM',1)
dados['Elogio a Instituição'] = dados['Elogio a Instituição'].replace('NÃO',0)

dados['Reclamação a Instituição'] = dados['Reclamação a Instituição'].replace('SIM',1)
dados['Reclamação a Instituição'] = dados['Reclamação a Instituição'].replace('NÃO',0)

dados['Elogio quanto ao app'] = dados['Elogio quanto ao app'].replace('SIM',1)
dados['Elogio quanto ao app'] = dados['Elogio quanto ao app'].replace('NÃO',0)
dados['Elogio quanto ao app'] = dados['Elogio quanto ao app'].replace('NAO',0)

dados['Reclamação quanto ao app'] = dados['Reclamação quanto ao app'].replace('SIM',1)
dados['Reclamação quanto ao app'] = dados['Reclamação quanto ao app'].replace('NÃO',0)


dados['Não Classificável'] = dados['Não Classificável'].replace('SIM',1)
dados['Não Classificável'] = dados['Não Classificável'].replace('NÃO',0)

dados
# Out:
#                   Instituição  \
# 0             Banco do Brasil
# 1             Banco do Brasil
# 2             Banco do Brasil
# 3             Banco do Brasil
# 4             Banco do Brasil
# ...                       ...
# 8697  Caixa Econômica Federal
# 8698  Caixa Econômica Federal
# 8699  Caixa Econômica Federal
# 8700  Caixa Econômica Federal
# 8701  Caixa Econômica Federal
#
#                                              Comentario       Data  \
# 0                                 Muito bom ajuda muito 2019-07-21
# 1                                             excelente 2019-07-21
# 2                                                   Bom 2019-07-21
# 3                                  aplicativo muito top 2019-07-21
# 4                                       Fácil e prático 2019-07-21
# ...                                                 ...        ...
# 8697                                          Muito bom 2020-08-24
# 8698                                                Top 2020-08-24
# 8699  A facilidade de resolver minhas movimentação b... 2020-08-24
# 8700                           Péssimo ,vou desinstalar 2020-08-24
# 8701                                                Boa 2020-08-24
#
#       Classificação  Elogio quanto ao app  Reclamação quanto ao app  \
# 0                 5                     1                         0
# 1                 5                     1                         0
# 2                 5                     1                         0
# 3                 5                     1                         0
# 4                 5                     1                         0
# ...             ...                   ...                       ...
# 8697              5                     1                         0
# 8698              5                     1                         0
# 8699              5                     1                         0
# 8700              1                     0                         1
# 8701              5                     1                         0
#
#       Elogio a Instituição  Reclamação a Instituição  Não Classificável
# 0                        0                         0                  0
# 1                        0                         0                  0
# 2                        0                         0                  0
# 3                        0                         0                  0
# 4                        0                         0                  0
# ...                    ...                       ...                ...
# 8697                     0                         0                  0
# 8698                     0                         0                  0
# 8699                     0                         0                  0
# 8700                     0                         0                  0
# 8701                     0                         0                  0
#
# [8702 rows x 9 columns]

# %%
dados['Elogio quanto ao app'].drop_duplicates()
# Out:
# 0     1
# 13    0
# Name: Elogio quanto ao app, dtype: int64

# %%
# Converter os dados para números
dados['Elogio a Instituição'] = dados['Elogio a Instituição'].astype(int)
dados['Elogio quanto ao app'] = dados['Elogio quanto ao app'].astype(int)
dados['Reclamação a Instituição'] = dados['Reclamação a Instituição'].astype(int)

# %%
#Fazendo as seguintes alterações
dados['Classificação'] = dados['Classificação'].replace(2,-1)
dados['Classificação'] = dados['Classificação'].replace(1,-1)
dados['Classificação'] = dados['Classificação'].replace(5,1)
dados['Classificação'] = dados['Classificação'].replace(4,1)
dados['Classificação'] = dados['Classificação'].replace(3,0)

# %%
# Calcular a média de classificação por instituição
dados_classificação = dados.groupby(['Instituição'])['Classificação'].agg('mean').reset_index()

dados_classificação['Classificação'] = dados_classificação['Classificação'] *100

# Criar o gráfico
sns.barplot(x = dados_classificação['Instituição'], y = dados_classificação['Classificação'])
# Out:
# <Axes: xlabel='Instituição', ylabel='Classificação'>

# %%
dados_ElogioReclamação = dados.groupby(['Elogio quanto ao app'])['Reclamação quanto ao app'].agg('mean').reset_index()


dados_ElogioReclamação['Elogio quanto ao app'] = dados_ElogioReclamação['Reclamação quanto ao app'] * 100

sns.barplot(x = dados_ElogioReclamação['Elogio quanto ao app'], y = dados_ElogioReclamação['Reclamação quanto ao app'])

# %%
dados_elogiosInstituição = dados.groupby(['Elogio quanto ao app'])['Reclamação a Instituição'].agg('mean').reset_index()

dados_elogiosInstituição['Elogio quanto ao app'] = dados_elogiosInstituição['Reclamação a Instituição'] * 100

sns.barplot(x = dados_elogiosInstituição['Elogio quanto ao app'], y = dados_elogiosInstituição['Reclamação a Instituição'])
